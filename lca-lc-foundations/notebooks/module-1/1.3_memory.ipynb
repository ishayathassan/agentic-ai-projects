# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="llama3.2:latest",
    temperature=0.2
)

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='439fbc95-5993-4c8e-994b-ea509c042d25'),
#               AIMessage(content="Hello Seán! It's great to meet you. Green is a wonderful colour, isn't it? From the lush forests to the vibrant hues of emeralds, there's something about green that just feels calming and natural. Do you have a particular shade of green that you prefer, or is it more of a general love for the colour?", additional_kwargs={}, response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-04-26T05:41:07.85109356Z', 'done': True, 'done_reason': 'stop', 'total_duration': 11094085084, 'load_duration': 3555059633, 'prompt_eval_count': 37, 'prompt_eval_duration': 1521522994, 'eval_count': 71, 'eval_duration': 5956468992, 'logprobs': None, 'model_name': 'llama3.2:latest', 'model_provider': 'ollama'}, id='lc_run--019dc84e-2132-75b2-9d65-668c8275be55-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 71, 'total_tokens': 108})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='bacc8590-316d-4e3b-bfdb-6ed8564a2055'),
#               AIMessage(content="I don't have any information about your personal preferences, including your favorite color. I'm a large language model, I don't have the ability to store or recall individual user data. Each time you interact with me, it's a new conversation.\n\nIf you'd like to share your favorite color with me, I'd be happy to chat with you about it!", additional_kwargs={}, response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-04-26T05:41:49.820177511Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7258693927, 'load_duration': 229274926, 'prompt_eval_count': 31, 'prompt_eval_duration': 520836798, 'eval_count': 74, 'eval_duration': 6448422261, 'logprobs': None, 'model_name': 'llama3.2:latest', 'model_provider': 'ollama'}, id='lc_run--019dc84e-d41d-7712-8670-9778a6af21c5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 74, 'total_tokens': 105})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  

model = ChatOllama(
    model="llama3.2:latest",
    temperature=0.2
)

agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='8a2c54da-774e-4cd5-b586-6d38fe44990c'),
#               AIMessage(content="Hello Seán! It's great to meet you. Green is a wonderful colour, isn't it? So calming and natural. Do you have a particular shade of green that you prefer - like lime, olive, or forest green?", additional_kwargs={}, response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-04-26T05:44:26.120826265Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4882536549, 'load_duration': 162535748, 'prompt_eval_count': 37, 'prompt_eval_duration': 733015956, 'eval_count': 48, 'eval_duration': 3948335585, 'logprobs': None, 'model_name': 'llama3.2:latest', 'model_provider': 'ollama'}, id='lc_run--019dc851-3ff3-7f63-b3cb-b1844d8f4a50-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 48, 'total_tokens': 85})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='8a2c54da-774e-4cd5-b586-6d38fe44990c'),
#               AIMessage(content="Hello Seán! It's great to meet you. Green is a wonderful colour, isn't it? So calming and natural. Do you have a particular shade of green that you prefer - like lime, olive, or forest green?", additional_kwargs={}, response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-04-26T05:44:26.120826265Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4882536549, 'load_duration': 162535748, 'prompt_eval_count': 37, 'prompt_eval_duration': 733015956, 'eval_count': 48, 'eval_duration': 3948335585, 'logprobs': None, 'model_name': 'llama3.2:latest', 'model_provider': 'ollama'}, id='lc_run--019dc851-3ff3-7f63-b3cb-b1844d8f4a50-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 48, 'total_tokens': 85}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='8c10747c-c542-4e07-8f64-430240faad1b'),
#               AIMessage(content='Your favourite colour is green!', additional_kwargs={}, response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-04-26T05:44:28.227566561Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1444454279, 'load_duration': 188280988, 'prompt_eval_count': 100, 'prompt_eval_duration': 717595211, 'eval_count': 7, 'eval_duration': 530786249, 'logprobs': None, 'model_name': 'llama3.2:latest', 'model_provider': 'ollama'}, id='lc_run--019dc851-559c-72a2-b317-7d98cd1d2da8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 100, 'output_tokens': 7, 'total_tokens': 107})]}
