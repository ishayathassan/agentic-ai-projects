# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
# from langchain.chat_models import init_chat_model

# model = init_chat_model(model="gpt-5-nano")

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="llama3.2:latest",
    temperature=0,
)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="There is no capital city on the Moon. The Moon is a natural satellite that orbits the Earth, and it does not have any permanent human settlements or governments. While there have been several manned missions to the Moon as part of NASA's Apollo program in the late 1960s and early 1970s, these were temporary visits and did not establish any permanent presence on the lunar surface.\n\nSo, there is no capital city on the Moon!", additional_kwargs={}, response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-04-25T19:46:30.74028104Z', 'done': True, 'done_reason': 'stop', 'total_duration': 11212425314, 'load_duration': 138864673, 'prompt_eval_count': 33, 'prompt_eval_duration': 124648186, 'eval_count': 91, 'eval_duration': 10847831168, 'logprobs': None, 'model_name': 'llama3.2:latest', 'model_provider': 'ollama'}, id='lc_run--019dc62d-bd05-7160-a9e9-b7401092ac64-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 33, 'output_tokens': 91, 'total_tokens': 124})

# %%
print(response.content)
# Out:
# There is no capital city on the Moon. The Moon is a natural satellite that orbits the Earth, and it does not have any permanent human settlements or governments. While there have been several manned missions to the Moon as part of NASA's Apollo program in the late 1960s and early 1970s, these were temporary visits and did not establish any permanent presence on the lunar surface.
#
# So, there is no capital city on the Moon!

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'created_at': '2026-04-25T19:46:30.74028104Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 91,
#  'eval_duration': 10847831168,
#  'load_duration': 138864673,
#  'logprobs': None,
#  'model': 'llama3.2:latest',
#  'model_name': 'llama3.2:latest',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 33,
#  'prompt_eval_duration': 124648186,
#  'total_duration': 11212425314}

# %% [markdown]
# ## Customising your Model

# %%
model = ChatOllama(
    model="llama3.2:latest",
    temperature=1,
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There is no capital of the Moon. The Moon is a natural satellite that orbits the Earth, and it does not have its own government or permanent human population. While there have been several manned missions to the Moon as part of NASA's Apollo program in the late 1960s and early 1970s, there are currently no established cities or settlements on the Moon.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city, or any cities at all for that matter. It's a natural celestial body with no human settlements or organized governments.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="llama3.2:latest",
    temperature=0,
)

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='df73a015-20b6-4ac9-bbe5-c672f93fc1eb'),
#               AIMessage(content="There is no capital city on the Moon. The Moon is a natural satellite that orbits the Earth, and it does not have any permanent human settlements or governments. While there have been several manned missions to the Moon as part of NASA's Apollo program in the late 1960s and early 1970s, these were temporary visits and did not establish any permanent presence on the lunar surface.\n\nSo, there is no capital city on the Moon!", additional_kwargs={}, response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-04-25T19:47:48.630251643Z', 'done': True, 'done_reason': 'stop', 'total_duration': 9965316526, 'load_duration': 119018287, 'prompt_eval_count': 33, 'prompt_eval_duration': 109155012, 'eval_count': 91, 'eval_duration': 9645154140, 'logprobs': None, 'model_name': 'llama3.2:latest', 'model_provider': 'ollama'}, id='lc_run--019dc62e-f226-72a2-becc-c6707c4406bf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 33, 'output_tokens': 91, 'total_tokens': 124})]}

# %%
response['messages'][0]
# Out:
# HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='df73a015-20b6-4ac9-bbe5-c672f93fc1eb')

# %%
print(response['messages'][-1].content)
# Out:
# There is no capital city on the Moon. The Moon is a natural satellite that orbits the Earth, and it does not have any permanent human settlements or governments. While there have been several manned missions to the Moon as part of NASA's Apollo program in the late 1960s and early 1970s, these were temporary visits and did not establish any permanent presence on the lunar surface.
#
# So, there is no capital city on the Moon!

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='0a73f7d7-0e5c-4319-b211-1d21e6713ee8'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='2299fcbd-e8b9-4889-8fc7-57d2a65ad37f', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='fe43cb64-1acd-4d13-bac9-cc9b90d2517f'),
#               AIMessage(content='I made a mistake earlier. There is no city called Luna City on the Moon. In fact, there are no permanent human settlements or cities on the Moon at all.\n\nHowever, I can tell you that the Moon does not have a capital city because it is not a country with a functioning government. The Moon is a natural satellite of Earth and has been explored by humans through space missions, but it is not inhabited by people and does not have its own political or administrative structures.\n\nI apologize for any confusion earlier!', additional_kwargs={}, response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-04-25T19:49:20.933879611Z', 'done': True, 'done_reason': 'stop', 'total_duration': 14032756190, 'load_duration': 134485367, 'prompt_eval_count': 60, 'prompt_eval_duration': 1632361098, 'eval_count': 104, 'eval_duration': 12153303126, 'logprobs': None, 'model_name': 'llama3.2:latest', 'model_provider': 'ollama'}, id='lc_run--019dc630-4ad3-7a60-b3b2-7869129a767a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 60, 'output_tokens': 104, 'total_tokens': 164})]}

# %%
print(response['messages'][-1].content)
# Out:
# I made a mistake earlier. There is no city called Luna City on the Moon. In fact, there are no permanent human settlements or cities on the Moon at all.
#
# However, I can tell you that the Moon does not have a capital city because it is not a country with a functioning government. The Moon is a natural satellite of Earth and has been explored by humans through space missions, but it is not inhabited by people and does not have its own political or administrative structures.
#
# I apologize for any confusion earlier!

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token

    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# I'm afraid I have to disappoint you. There is no city called "Luna City" that serves as the capital of the Moon. While there have been several manned missions to the Moon in the past, including those by NASA's Apollo program, no human settlement or permanent city has been established on the lunar surface.
#
# However, there are plans to establish a sustainable presence on the Moon in the near future. For example, NASA's Artemis program aims to return humans to the Moon by 2025 and establish a sustainable presence on the lunar surface by the 2020s. Private companies such as SpaceX and Blue Origin are also working towards establishing a human settlement on the Moon.
#
# If you're interested in learning more about potential lunar cities or settlements, I'd be happy to provide information on some of the concepts and proposals that have been put forward.
